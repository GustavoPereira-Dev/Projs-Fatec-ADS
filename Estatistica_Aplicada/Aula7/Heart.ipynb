# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
heart = pd.read_csv("/content/drive/MyDrive/Aulas Estatística (Python)/Lab1/heart.csv",
                      sep=",",encoding="iso-8859-1")

# %%
heart.shape
# Out:
# (918, 12)

# %%
heart.head(20)
# Out:
#     Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0    40   M           ATA        140          289          0     Normal
# 1    49   F           NAP        160          180          0     Normal
# 2    37   M           ATA        130          283          0         ST
# 3    48   F           ASY        138          214          0     Normal
# 4    54   M           NAP        150          195          0     Normal
# 5    39   M           NAP        120          339          0     Normal
# 6    45   F           ATA        130          237          0     Normal
# 7    54   M           ATA        110          208          0     Normal
# 8    37   M           ASY        140          207          0     Normal
# 9    48   F           ATA        120          284          0     Normal
# 10   37   F           NAP        130          211          0     Normal
# 11   58   M           ATA        136          164          0         ST
# ...

# %%
heart.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %% [markdown]
# **1 -	Qual a quantidade total de registros?**

# %%
total = len(heart)
total # total registros
# Out:
# 918

# %% [markdown]
# **2 - Determine a média, a moda, a mediana, o desvio padrão e a variância da variável idade.**

# %%
heart.Age.mean() # Média
# Out:
# 53.510893246187365

# %%
heart.Age.mode() # Moda
# Out:
# 0    54
# Name: Age, dtype: int64

# %%
heart.Age.median() # Mediana
# Out:
# 54.0

# %%
heart.Age.std() # Desvio padrão
# Out:
# 9.432616506732007

# %%
heart.Age.var() # Variância
# Out:
# 88.97425416307314

# %% [markdown]
# **3 - Construa um histograma para a variável idade.**

# %%
import plotly.express as px
grafico =  px.histogram (heart,  x = "Age", nbins=10)
grafico.update_layout(width=500,height=400,title_text='Histograma de Idade')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **4 -	Para a variável idade, a média é uma medida que representa a centralidade dos dados? Justifique a resposta.**
#
# R: Bem, nesse caso sim, pois a média não está muito distante da mediana (e o gráfico demonstra uma distribuição razoavelmente siméstrica). Contudo, se os valores de idades fossem ainda mais discrepantes (O que causaria uma distância enorme entre média e mediana) uma medida central seria a mediana

# %% [markdown]
# **5 - Determine a quantidade de pessoas do sexo feminino e do sexo masculino em porcentagem.**

# %%
quant_mulheres = len(heart[heart['Sex'] == 'F']) # Quantidade mulheres
np.round((quant_mulheres / total) * 100,2) # Porcentagem mulheres
# Out:
# 21.02

# %%
quant_homens = len(heart[heart['Sex'] == 'M']) # Quantidade homens
np.round((quant_homens / total) * 100, 2) # Porcentagem homens
# Out:
# 78.98

# %% [markdown]
# **6 - Determine os valores máximo, mínimo e os quartis para a variável colesterol. Construa um gráfico BoxPlot.**

# %%
heart["Cholesterol"].max() # Máximo
# Out:
# 603

# %%
heart["Cholesterol"].min() # Mínimo
# Out:
# 0

# %%
heart["Cholesterol"].quantile(q=0.25) # Q1
# Out:
# 173.25

# %%
heart["Cholesterol"].quantile(q=0.5) # Q2 (Mediana)
# Out:
# 223.0

# %%
heart["Cholesterol"].quantile(q=0.75) # Q3
# Out:
# 267.0

# %%
# Gráfico BoxPlot de colesterol
import plotly.express as px
grafico = px.box(heart, y="Cholesterol")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **7 - A variável colesterol possui outliers? Se sim, estes valores outliers são coerentes com a realidade? Qual a sua sugestão para lidar com estes outliers (manter, excluir, alterar...)?**
#
# R: Colesterol possuí bastantes outliers por sinal, contudo é coerente com a realidade (pois existem tanto pessoas com sequer colesterol ou zero quanto pessoas com uma quantidade que é perigosa demais até para a pessoa)
# O certo seria remover esses outliers do cálculo como um todo e calcular eles de uma forma avulsa (pois podem ser relevantes para ver, por exemplo alguns fatores que pode fazer com que a pessoa fique com mais ou menos colesterol)
# Fazendo esses cuidados de limpeza e separação dos outliers, será reduzido a sua influência nos resultados dos cálculos

# %% [markdown]
# **8 - Qual a probabilidade de sortear ao acaso uma pessoa do sexo feminino com idade inferior a 35 anos?**

# %%
sortear_menor_35 = len(heart[heart['Age'] < 35]) / len(heart) # 2.28% de sortear uma pessoa com idade inferior a 35
sortear_menor_35
# Out:
# 0.02287581699346405

# %%
sortear_mulher = len(heart[heart['Sex'] == "F"]) / len(heart) # 21.02% a possibilidade de sortear uma mulher
sortear_mulher
# Out:
# 0.210239651416122

# %%
sortear_mulher - sortear_menor_35 # probabilidade de sortear uma pessoa do sexo feminino com idade inferior a 35 anos
# Out:
# 0.18736383442265794

# %%
# prompt: Qual a probabilidade de sortear ao acaso uma pessoa do sexo feminino com idade inferior a 35 anos?
# Resposta correta
# Calculando a probabilidade de uma pessoa ser mulher E ter menos de 35 anos.
mulheres_menos_35 = len(heart[(heart['Sex'] == 'F') & (heart['Age'] < 35)])
probabilidade = mulheres_menos_35 / len(heart)
print(f"A probabilidade de sortear uma mulher com menos de 35 anos é: {probabilidade:.4f}")
# Out:
# A probabilidade de sortear uma mulher com menos de 35 anos é: 0.0065

# %% [markdown]
# **9 - Qual a probabilidade de sortear uma pessoa com idade entre 20 anos e 35 anos de idade.**

# %%
menor_20 = len(heart[heart['Age'] < 20]) / len(heart)

# %%
maior_35 = len(heart[heart['Age'] > 35]) / len(heart)

# %%
np.round((1 - (menor_20 + maior_35)) * 100,2) # probabilidade de sortear uma pessoa com idade entre 20 anos e 35 anos (Porcentagem)
# Out:
# 3.49

# %% [markdown]
# **10 - Em 20 sorteios, qual a probabilidade de saírem até 8 pessoas com doença cardíaca?**

# %%
from scipy.stats import binom

# %%
com_problema_coracao = len(heart[heart["HeartDisease"] == 1]) / len(heart)
binom.cdf(8,20,com_problema_coracao) # probabilidade de saírem até 8 pessoas com doença cardíaca em 20 sorteios
# Out:
# 0.12432473548273305

# %% [markdown]
# **11 - A variável Chest Pain Type (tipo de dor no peito) possui as seguintes classes:**
#
# **TA: angina típica; ATA: angina atípica; NAP: dor não anginosa; ASY: assintomático.**
#
# **Construa uma tabela com a frequência absoluta de cada classe.**

# %%
heart['ChestPainType'].value_counts() # Frequência absoluta das classes
# Out:
# ChestPainType
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: count, dtype: int64
